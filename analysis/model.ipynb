# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from pathlib import Path
import warnings

warnings.filterwarnings('ignore')

data_path = Path().cwd() / 'data'

# %%
test_sheet = 'test_points_spec_extracted.xls'
test_sites = pd.read_excel(data_path / test_sheet, engine='calamine')

test_sites.drop(columns=[col for col in test_sites.columns if 'NEAR_FID' in col], inplace=True)

test_sites.rename(columns={
        'RASTERVALU': 'Elevation'
    }, inplace=True)


print(test_sites.shape)
test_sites.head()
# Out:
# (25459, 31)
#    OBJECTID          x         y  NEAR_DIST_Canals  NEAR_DIST_River_Net  \
# 0         1  16.216378  42.75412     374896.416513         86925.777533
# 1         2  16.232699  42.75412     376010.324268         86329.484792
# 2         3  16.249020  42.75412     377125.532090         85749.632286
# 3         4  16.265341  42.75412     378242.028437         85186.555754
# 4         5  16.281663  42.75412     379359.801958         84640.589997
#
#    NEAR_DIST_Coastal  NEAR_DIST_Chert  WAW_2018_010m_E45N24_03035_v020  \
# 0       21529.164668     24078.397439                              NaN
# 1       20193.162744     22746.485743                              NaN
# 2       18857.185726     21415.079367                              NaN
# 3       17521.239367     20084.278860                              NaN
# 4       16185.331232     18754.213174                              NaN
#
#    WAW_2018_010m_E46N23_03035_v020  WAW_2018_010m_E46N24_03035_v020  ...  \
# 0                              NaN                              NaN  ...
# 1                              NaN                              NaN  ...
# 2                              NaN                              NaN  ...
# 3                              NaN                              NaN  ...
# 4                              NaN                              NaN  ...
#
#    WAW_2018_010m_E48N26_03035_v020  WAW_2018_010m_E49N21_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E49N22_03035_v020  WAW_2018_010m_E49N24_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E49N25_03035_v020  WAW_2018_010m_E50N21_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E50N22_03035_v020  WAW_2018_010m_E50N24_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E50N25_03035_v020  Elevation
# 0                              NaN        NaN
# 1                              NaN        NaN
# 2                              NaN        NaN
# 3                              NaN        NaN
# 4                              NaN        NaN
#
# [5 rows x 31 columns]

# %%
def clean_waw(df: pd.DataFrame):
    wcols = [col for col in df.columns if 'WAW' in col]
    waw = df[wcols + ['OBJECTID']]
    df.drop(columns=wcols, inplace=True)
    
    waw['Wetness'] = waw[waw.drop(['OBJECTID'], axis=1).columns].apply(
        lambda x: ''.join(x.dropna().astype(str)), 
        axis=1
    )
    
    waw = waw[waw['Wetness'] != ''][['OBJECTID', 'Wetness']]
    waw['Wetness'] = waw['Wetness'].astype(float).astype(np.uint8)
    return pd.merge(df, waw, on='OBJECTID', how='inner')

# %%
test_cleaned = clean_waw(test_sites)
test_cleaned
# Out:
#        OBJECTID          x          y  NEAR_DIST_Canals  NEAR_DIST_River_Net  \
# 0             1  16.216378  42.754120     374896.416513         86925.777533
# 1             2  16.232699  42.754120     376010.324268         86329.484792
# 2             3  16.249020  42.754120     377125.532090         85749.632286
# 3             4  16.265341  42.754120     378242.028437         85186.555754
# 4             5  16.281663  42.754120     379359.801958         84640.589997
# ...         ...        ...        ...               ...                  ...
# 25355     25455  16.004201  44.676145     184989.356662          2271.270992
# 25356     25456  16.004201  44.685430     183977.412603          3259.110714
# 25357     25457  16.020522  44.657574     186768.663311            41.657071
# 25358     25458  16.020522  44.666859     185754.992778          1064.431584
# 25359     25459  16.036843  44.657574     186531.839857           588.634010
#
#        NEAR_DIST_Coastal  NEAR_DIST_Chert   Elevation  Wetness
# 0           21529.164668     24078.397439         NaN      255
# 1           20193.162744     22746.485743         NaN      255
# 2           18857.185726     21415.079367         NaN      255
# 3           17521.239367     20084.278860         NaN      255
# 4           16185.331232     18754.213174         NaN      255
# ...                  ...              ...         ...      ...
# 25355       59132.748107     90956.384346  551.129211        0
# 25356       59923.992081     91942.567948  659.387390        0
# 25357       58440.290816     88604.594675  337.125427        0
# 25358       59204.693096     89592.956286  400.164185        0
# 25359       59323.222735     88239.645786  532.479248        0
#
# [25360 rows x 9 columns]

# %%
display(test_cleaned.isna().sum().to_frame().T)

test_cleaned.dropna(inplace=True)

display(test_cleaned.isna().sum().to_frame().T)
# Out:
#    OBJECTID  x  y  NEAR_DIST_Canals  NEAR_DIST_River_Net  NEAR_DIST_Coastal  \
# 0         0  0  0                 0                    0                  0
#
#    NEAR_DIST_Chert  Elevation  Wetness
# 0                0      10208        0
#    OBJECTID  x  y  NEAR_DIST_Canals  NEAR_DIST_River_Net  NEAR_DIST_Coastal  \
# 0         0  0  0                 0                    0                  0
#
#    NEAR_DIST_Chert  Elevation  Wetness
# 0                0          0        0

# %%
test_cleaned.to_csv(data_path / f'{test_sheet}_cleaned.csv', index=False)

# %%
known_sites = pd.read_excel(data_path / 'known_sites_augmented.xls', engine='calamine')

known_sites.rename(columns={
        i: i.replace('sites_XYTableToPoint_', '') for i in known_sites.columns if 'sites_XYTableToPoint_' in i
    }, inplace=True)

known_sites.rename(columns={
    'Elevation__Masl_': 'Elevation',
    'Dd_ns': 'y',
    'Dd_ew': 'x',
    }, inplace=True)

known_sites.drop(columns=['Dd', 'Dms'] + [col for col in known_sites.columns if 'NEAR_FID' in col], inplace=True)

print(known_sites.shape)
known_sites.head()
# Out:
# (47, 37)
#    OBJECTID                Site_Name Geographical_Region  \
# 0         1         Abri Kontija 002               Istra
# 1         2               Abri Šebrn                 NaN
# 2         3  Brjgućeva Loza 1 (Loza)               Istra
# 3         4                  Bukovac                 NaN
# 4         5                 Campanož                 NaN
#
#   Geographical_Location  Elevation Period_New Site_Type          y          x  \
# 0          Limski kanal       46.0         UP        RS  45.137500  13.718611
# 1                   NaN      750.0        MES        RS  45.337712  14.162687
# 2                Kastav      510.0        MES         C  45.467778  14.242222
# 3                   NaN      864.0         UP         C  45.346569  14.756238
# 4                   NaN        NaN         MP         O  44.849045  13.899990
#
#    NEAR_DIST_Chert  ...  WAW_2018_010m_E48N25_03035_v020  \
# 0    247901.167568  ...                              NaN
# 1    235748.803581  ...                              NaN
# 2    241293.250685  ...                              NaN
# 3    204549.089663  ...                              NaN
# 4    215799.109406  ...                              NaN
#
#    WAW_2018_010m_E48N26_03035_v020  WAW_2018_010m_E49N21_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E49N22_03035_v020  WAW_2018_010m_E49N24_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E49N25_03035_v020  WAW_2018_010m_E50N21_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E50N22_03035_v020  WAW_2018_010m_E50N24_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E50N25_03035_v020
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 37 columns]

# %%
known_sites_cleaned = clean_waw(known_sites).drop(columns=['Geographical_Region', 'Geographical_Location', 'Period_New', 'Site_Type'])

cols = known_sites_cleaned.columns
known_sites_cleaned = known_sites_cleaned[cols[:3].to_list() + [cols[-2]] + cols[3:-2].to_list() + [cols[-1]]]

print(known_sites_cleaned.shape)
known_sites_cleaned.head()
# Out:
# (47, 11)
#    OBJECTID                Site_Name  Elevation  RASTERVALU          y  \
# 0         1         Abri Kontija 002       46.0   46.136692  45.137500
# 1         2               Abri Šebrn      750.0  732.561707  45.337712
# 2         3  Brjgućeva Loza 1 (Loza)      510.0  432.515076  45.467778
# 3         4                  Bukovac      864.0  791.070129  45.346569
# 4         5                 Campanož        NaN   43.708790  44.849045
#
#            x  NEAR_DIST_Chert  NEAR_DIST_Canals  NEAR_DIST_River_Net  \
# 0  13.718611    247901.167568      80993.524258         73640.087050
# 1  14.162687    235748.803581      98999.561639         44437.690620
# 2  14.242222    241293.250685     101016.428031         34876.914519
# 3  14.756238    204549.089663     143240.912311         13416.969148
# 4  13.899990    215799.109406     114332.595817         94426.986888
#
#    NEAR_DIST_Coastal  Wetness
# 0        7612.808936        0
# 1        9921.595682        0
# 2       14119.067154        0
# 3       15491.977574        0
# 4        2230.743465        0

# %%
known_sites_cleaned.Elevation.fillna(known_sites_cleaned.RASTERVALU, inplace=True)
known_sites_cleaned.Elevation.fillna(0, inplace=True)

known_sites_cleaned.drop(columns='RASTERVALU', inplace=True)

known_sites_cleaned['Is_Site'] = 0

known_sites_cleaned
# Out:
#     OBJECTID                         Site_Name   Elevation          y  \
# 0          1                  Abri Kontija 002   46.000000  45.137500
# 1          2                        Abri Šebrn  750.000000  45.337712
# 2          3           Brjgućeva Loza 1 (Loza)  510.000000  45.467778
# 3          4                           Bukovac  864.000000  45.346569
# 4          5                          Campanož   43.708790  44.849045
# 5          6                  Cerovačke pećine  624.000000  44.274628
# 6          7          Giljanovići (Karanušići)  154.000000  43.940833
# 7          8                         Glavičica  295.000000  43.749998
# 8          9                  Gospodska špilja  430.000000  43.983887
# 9         10                   Igraliste-Dolac   16.000000  44.142032
# 10        11                           Ivšišće   24.520134  45.198816
# 11        12                     Jami na sredi  102.000000  44.666660
# 12        13          Kaštel Štafilić – Resnik    0.000000  43.538609
# 13        14                     Klanjčeva peć  828.000000  45.333050
# 14        15                     Kopačina cave  280.000000  43.353049
# 15        16             Krševanje polje, Sali   23.944098  43.916839
# 16        17                           Lim 001    0.000000  45.133916
# 17        18                  Ljubićeva pećina  170.000000  44.971800
# 18        19                             Lopar   20.000000  44.833333
# 19        20                  Malo Polje Krban   19.260384  43.525783
# 20        21                     Mujina pećina  260.000000  43.525775
# 21        22                           Okruglo  297.810455  43.750000
# 22        23  Panjorovica/Panđerovica Veli Rat    8.000000  44.150237
# 23        24                 Pećina na Gradini  393.000000  45.333332
# 24        25      Pećina kod Rovinjskog Sela 1   71.000000  45.126527
# 25        26            Pećina u Brini zapadna  250.000000  43.833331
# 26        27                     Podosojna peć  335.000000  45.260578
# 27        28               Podumci kod Unešića  295.000000  43.716667
# 28        29                             Polje    4.000000  44.134675
# 29        30                   Ražanac cluster  102.495941  44.253355
# 30        31                 Romualdova pećina  110.000000  45.136331
# 31        32                         Savudrija    5.337913  45.501000
# 32        33      Stipanac, Prokljansko Jezero    0.000000  43.816660
# 33        34                            Straža   20.000000  44.140877
# 34        35                       Šandalja II   72.000000  44.882492
# 35        36               Uvala čuna-Darstalo    1.000000  44.135599
# 36        37                   Uvala Jaz-Polje    1.000000  44.135395
# 37        38     Valačin žal- Uvala Podlokvanj    2.000000  44.159398
# 38        39                Vela Spila Korčula  130.000000  42.970325
# 39        40       Vela Jama/spilja na Lošinju  450.000000  44.671849
# 40        41           Velika pećina Kličevica  125.000000  44.030832
# 41        42                Vergotinova pećina   85.000000  45.284167
# 42        43                    Vorganjska peć  251.000000  44.975890
# 43        44                            Vlakno   38.000000  44.036743
# 44        45                   Zametska pećina  140.000000  45.346731
# 45        46                 Zapuntelsko polje   28.055592  44.249722
# 46        47                          Zemunica  591.057983  43.563169
#
#             x  NEAR_DIST_Chert  NEAR_DIST_Canals  NEAR_DIST_River_Net  \
# 0   13.718611    247901.167568      80993.524258         73640.087050
# 1   14.162687    235748.803581      98999.561639         44437.690620
# 2   14.242222    241293.250685     101016.428031         34876.914519
# 3   14.756238    204549.089663     143240.912311         13416.969148
# 4   13.899990    215799.109406     114332.595817         94426.986888
# 5   15.884619     55816.576622     230558.124333         13364.401168
# 6   16.426389      8763.044136     263072.737065         24402.718149
# 7   16.666664     16125.218641     283521.439121           128.942963
# 8   16.436379     12714.582519     258279.688979         27729.070919
# 9   14.841416    108346.908403     208949.862435         62981.253902
# 10  14.098523    229615.033310     100969.707721         56402.829540
# 11  14.466665    169087.564495     159865.009412         60180.963870
# 12  16.312500      1015.417553     307995.359885         32011.895604
# 13  14.187772    233944.879546     101023.266085         42841.545086
# 14  16.552514      4960.723478     322274.983016         16283.969084
# 15  15.154990     73594.575338     239987.590332         53236.680674
# 16  13.731182    246911.612526      81981.787300         74303.386795
# 17  13.951898    221892.824957     107006.480994         81614.812642
# 18  14.750000    164142.625069     166006.416391         37582.604374
# 19  16.264043      1100.235621     309598.338527         36075.488942
# 20  16.244627      1516.954994     309684.214652         37630.906593
# 21  16.666667     16125.508022     283521.111193           129.186084
# 22  14.827839    109760.311095     207681.326635         62936.151156
# 23  14.499993    216549.206854     124243.673966         22827.055656
# 24  13.703193    247940.859038      80989.241048         74487.350950
# 25  16.166664     15386.116678     276040.804312         17249.593138
# 26  14.198106    227981.751358     104832.974734         46066.475890
# 27  16.133333     15547.831158     289188.546432         24696.729915
# 28  14.861064    106591.594746     210670.266998         62695.434565
# 29  15.402970     84960.700280     240851.826880         23953.173334
# 30  13.654845    251462.610421      77563.259735         72524.502562
# 31  13.505000    286946.056347      44428.287617         30535.279575
# 32  15.866655     27591.807756     280916.740849         13648.016031
# 33  14.835754    108643.248861     208539.576298         63359.695949
# 34  13.896656    218422.055966     111307.467109         91816.507433
# 35  14.856929    106920.806456     210324.479034         62807.505004
# 36  14.860817    106654.086647     210632.166421         62642.319611
# 37  14.824865    110545.248464     207216.820971         62297.692034
# 38  16.718319      1409.275742     347978.719535         52210.121861
# 39  14.355378    175796.552672     153139.189031         68794.150482
# 40  15.558308     59221.739116     262257.910763         21483.647715
# 41  13.655270    262892.876393      66593.109933         56599.365672
# 42  14.738947    175174.403405     157072.010656         44336.242348
# 43  15.028027     89393.220467     226363.682808         56155.250186
# 44  14.386030    223804.339613     115262.490702         28493.833741
# 45  14.807778    117738.899999     203833.285641         55929.511322
# 46  16.673991     14937.567129     298220.154725          2709.862711
#
#     NEAR_DIST_Coastal  Wetness  Is_Site
# 0         7612.808936        0        0
# 1         9921.595682        0        0
# 2        14119.067154        0        0
# 3        15491.977574        0        0
# 4         2230.743465        0        0
# 5        27505.569553        0        0
# 6        43623.324044        4        0
# 7        28440.487128        0        0
# 8        48470.385061        0        0
# 9          242.634165        0        0
# 10        9032.250894        0        0
# 11        2242.682827        0        0
# 12           0.000000      253        0
# 13        7902.780346        0        0
# 14        3439.111189        0        0
# 15          91.850254        0        0
# 16        8223.096752      253        0
# 17        6584.171801        0        0
# 18         340.311413        0        0
# 19         421.096336        0        0
# 20         924.156515        0        0
# 21       28440.804905        0        0
# 22         378.911507        0        0
# 23        2382.657946        0        0
# 24        5920.852677        0        0
# 25       23503.165074        0        0
# 26        5139.917317        0        0
# 27       14569.474237        0        0
# 28          77.846921        0        0
# 29         495.456951        0        0
# 30        4077.963352        0        0
# 31          67.922653        0        0
# 32        9414.608788      253        0
# 33         140.241024        0        0
# 34        3843.915771        0        0
# 35           0.000000      253        0
# 36           0.000000        0        0
# 37          24.303937        0        0
# 38         434.986087        0        0
# 39         935.033241        0        0
# 40       12973.428215        0        0
# 41        4000.124985        0        0
# 42        1302.346362        0        0
# 43          98.568997        0        0
# 44         996.177126        0        0
# 45         928.227203        0        0
# 46       12781.874307        0        0

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
known = known_sites_cleaned.drop(columns=['OBJECTID', 'x', 'y', 'Site_Name'])
test = test_cleaned.drop(columns=['OBJECTID', 'x', 'y'])

col_order = ['Elevation', 'Wetness', 'NEAR_DIST_Chert', 'NEAR_DIST_Canals',	'NEAR_DIST_River_Net', 'NEAR_DIST_Coastal']

known = known[col_order + ['Is_Site']]
test = test[col_order]

# %%
known.head()
# Out:
#    Elevation  Wetness  NEAR_DIST_Chert  NEAR_DIST_Canals  NEAR_DIST_River_Net  \
# 0   46.00000        0    247901.167568      80993.524258         73640.087050
# 1  750.00000        0    235748.803581      98999.561639         44437.690620
# 2  510.00000        0    241293.250685     101016.428031         34876.914519
# 3  864.00000        0    204549.089663     143240.912311         13416.969148
# 4   43.70879        0    215799.109406     114332.595817         94426.986888
#
#    NEAR_DIST_Coastal  Is_Site
# 0        7612.808936        0
# 1        9921.595682        0
# 2       14119.067154        0
# 3       15491.977574        0
# 4        2230.743465        0

# %%
test.head()
# Out:
#       Elevation  Wetness  NEAR_DIST_Chert  NEAR_DIST_Canals  \
# 182   22.511099        0       792.107078     376552.349498
# 183   49.590641        0       243.292773     375700.235383
# 515   22.922960        0      5785.026601     367912.519382
# 544   76.798393        0      4213.535219     364598.470742
# 548  134.343857        0      5871.037123     364798.267839
#
#      NEAR_DIST_River_Net  NEAR_DIST_Coastal
# 182         77429.587911          45.335448
# 183         76428.133607         123.823975
# 515         76214.050216          62.423273
# 544         73602.265456         177.921794
# 548         72905.089059         238.423757

# %%
train_known, test_known = train_test_split(known, test_size=0.2, random_state=42)

X_train = train_known.drop(columns='Is_Site')
y_train = train_known['Is_Site']

X_test = test_known.drop(columns='Is_Site')
y_test = test_known['Is_Site']

# %%
model = xgb.XGBClassifier()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred.round())*100}%')
# Out:
# Accuracy: 100.0%

# %%
outcome = test.copy()
outcome['prediction'] = model.predict(outcome)
outcome.nunique().to_frame().T
# Out:
#    Elevation  Wetness  NEAR_DIST_Chert  NEAR_DIST_Canals  NEAR_DIST_River_Net  \
# 0      15071        6            15152             15152                15148
#
#    NEAR_DIST_Coastal  prediction
# 0              15152           1
