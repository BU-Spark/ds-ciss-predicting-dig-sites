# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from pathlib import Path
import warnings

warnings.filterwarnings('ignore')

data_path = Path().cwd() / 'data'

# %%
test_sheet = 'test_points_extracted.xls'
test_sites = pd.read_excel(data_path / test_sheet, engine='calamine')

test_sites.drop(columns=[col for col in test_sites.columns if 'NEAR_FID' in col], inplace=True)

print(test_sites.shape)
test_sites.head()
# Out:
# (12067, 12)
#    OBJECTID_1  OBJECTID          x          y  NEAR_DIST_Canals  \
# 0           1      3353  15.726739  43.023390     325051.049972
# 1           2      3357  15.743060  43.023390     326171.018246
# 2           3      3362  15.759382  43.023390     327292.421342
# 3           4      3410  15.759382  43.032675     326739.480379
# 4           5       183  16.510161  42.763406     376552.349498
#
#    NEAR_DIST_River_Net  NEAR_DIST_Coastal  NEAR_DIST_Chert   Elevation  \
# 0         92375.044496         109.719805     27245.870159   70.596275
# 1         91240.568066         521.790859     25924.985926  227.165344
# 2         90111.311563         128.050137     24605.088261   41.271420
# 3         89566.947218         238.350808     24494.102940   58.482124
# 4         77429.587911          45.335448       792.107078   22.511099
#
#    Wetness       Temp  Slope
# 0        0  16.799999    207
# 1        0  16.400000    243
# 2        0  17.100000    236
# 3        0  16.500000    232
# 4        0  17.000000    242

# %%
def clean_waw(df: pd.DataFrame):
    wcols = [col for col in df.columns if 'WAW' in col]
    waw = df[wcols + ['OBJECTID']]
    df.drop(columns=wcols, inplace=True)
    
    waw['Wetness'] = waw[waw.drop(['OBJECTID'], axis=1).columns].apply(
        lambda x: ''.join(x.dropna().astype(str)), 
        axis=1
    )
    
    waw = waw[waw['Wetness'] != ''][['OBJECTID', 'Wetness']]
    waw['Wetness'] = waw['Wetness'].astype(float).astype(np.uint8)
    return pd.merge(df, waw, on='OBJECTID', how='inner')

# %%
if any('WAW' in col for col in test_sites.columns):
    test_cleaned = clean_waw(test_sites)

else:
    test_cleaned = test_sites.copy()
    
test_cleaned.dropna(inplace=True)

test_cleaned.to_csv(data_path / f"{test_sheet.split('.')[0]}_cleaned.csv", index=False)

# %%
known_sites = pd.read_excel(data_path / 'known_sites_augmented.xls', engine='calamine')

known_sites.rename(columns={
        i: i.replace('sites_XYTableToPoint_', '') for i in known_sites.columns if 'sites_XYTableToPoint_' in i
    }, inplace=True)

known_sites.rename(columns={
    'Elevation__Masl_': 'Elevation',
    'Dd_ns': 'y',
    'Dd_ew': 'x',
    }, inplace=True)

known_sites.drop(columns=['Dd', 'Dms'] + [col for col in known_sites.columns if 'NEAR_FID' in col], inplace=True)

print(known_sites.shape)
known_sites.head()
# Out:
# (47, 39)
#    OBJECTID                Site_Name Geographical_Region  \
# 0         1         Abri Kontija 002               Istra
# 1         2               Abri Šebrn                 NaN
# 2         3  Brjgućeva Loza 1 (Loza)               Istra
# 3         4                  Bukovac                 NaN
# 4         5                 Campanož                 NaN
#
#   Geographical_Location  Elevation Period_New Site_Type          y          x  \
# 0          Limski kanal       46.0         UP        RS  45.137500  13.718611
# 1                   NaN      750.0        MES        RS  45.337712  14.162687
# 2                Kastav      510.0        MES         C  45.467778  14.242222
# 3                   NaN      864.0         UP         C  45.346569  14.756238
# 4                   NaN        NaN         MP         O  44.849045  13.899990
#
#    NEAR_DIST_Chert  ...  WAW_2018_010m_E49N21_03035_v020  \
# 0    247901.167568  ...                              NaN
# 1    235748.803581  ...                              NaN
# 2    241293.250685  ...                              NaN
# 3    204549.089663  ...                              NaN
# 4    215799.109406  ...                              NaN
#
#    WAW_2018_010m_E49N22_03035_v020  WAW_2018_010m_E49N24_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E49N25_03035_v020  WAW_2018_010m_E50N21_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E50N22_03035_v020  WAW_2018_010m_E50N24_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E50N25_03035_v020  Slope  Temp
# 0                              NaN    204  15.7
# 1                              NaN    241  11.0
# 2                              NaN    247  12.4
# 3                              NaN    245   9.7
# 4                              NaN    250  15.7
#
# [5 rows x 39 columns]

# %%
known_sites_cleaned = clean_waw(known_sites).drop(columns=['Geographical_Region', 'Geographical_Location', 'Period_New', 'Site_Type'])

cols = known_sites_cleaned.columns
known_sites_cleaned = known_sites_cleaned[cols[:3].to_list() + [cols[-2]] + cols[3:-2].to_list() + [cols[-1]]]

known_sites_cleaned.Elevation.fillna(known_sites_cleaned.Elevation_Raster, inplace=True)
known_sites_cleaned.Elevation.fillna(0, inplace=True)

known_sites_cleaned.drop(columns=['Elevation_Raster'], inplace=True)

known_sites_cleaned['Is_Site'] = 1

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
print(f'known columns: {known_sites_cleaned.columns}')
print(f'test columns: {test_cleaned.columns}')
# Out:
# known columns: Index(['OBJECTID', 'Site_Name', 'Elevation', 'Temp', 'y', 'x',
#        'NEAR_DIST_Chert', 'NEAR_DIST_Canals', 'NEAR_DIST_River_Net',
#        'NEAR_DIST_Coastal', 'Slope', 'Wetness', 'Is_Site'],
#       dtype='object')
# test columns: Index(['OBJECTID_1', 'OBJECTID', 'x', 'y', 'NEAR_DIST_Canals',
#        'NEAR_DIST_River_Net', 'NEAR_DIST_Coastal', 'NEAR_DIST_Chert',
#        'Elevation', 'Wetness', 'Temp', 'Slope'],
#       dtype='object')

# %%
known = known_sites_cleaned.drop(columns=['OBJECTID', 'x', 'y', 'Site_Name'])
test = test_cleaned.drop(columns=['OBJECTID', 'x', 'y'])

col_order = ['Elevation', 'Wetness', 'Temp', 'Slope', 'NEAR_DIST_Chert', 'NEAR_DIST_Canals', 'NEAR_DIST_River_Net', 'NEAR_DIST_Coastal']

known = known[col_order + ['Is_Site']]
test = test[col_order]

test.reset_index(drop=True, inplace=True)

# %%
known.head()
# Out:
#    Elevation  Wetness  Temp  Slope  NEAR_DIST_Chert  NEAR_DIST_Canals  \
# 0   46.00000        0  15.7    204    247901.167568      80993.524258
# 1  750.00000        0  11.0    241    235748.803581      98999.561639
# 2  510.00000        0  12.4    247    241293.250685     101016.428031
# 3  864.00000        0   9.7    245    204549.089663     143240.912311
# 4   43.70879        0  15.7    250    215799.109406     114332.595817
#
#    NEAR_DIST_River_Net  NEAR_DIST_Coastal  Is_Site
# 0         73640.087050        7612.808936        1
# 1         44437.690620        9921.595682        1
# 2         34876.914519       14119.067154        1
# 3         13416.969148       15491.977574        1
# 4         94426.986888        2230.743465        1

# %%
test.head()
# Out:
#     Elevation  Wetness       Temp  Slope  NEAR_DIST_Chert  NEAR_DIST_Canals  \
# 0   70.596275        0  16.799999    207     27245.870159     325051.049972
# 1  227.165344        0  16.400000    243     25924.985926     326171.018246
# 2   41.271420        0  17.100000    236     24605.088261     327292.421342
# 3   58.482124        0  16.500000    232     24494.102940     326739.480379
# 4   22.511099        0  17.000000    242       792.107078     376552.349498
#
#    NEAR_DIST_River_Net  NEAR_DIST_Coastal
# 0         92375.044496         109.719805
# 1         91240.568066         521.790859
# 2         90111.311563         128.050137
# 3         89566.947218         238.350808
# 4         77429.587911          45.335448

# %%
test.loc[(test['Elevation'] > 400), 'Is_Site'] = 0
test.loc[(test['Elevation'] <= 400), 'Is_Site'] = 1
# test.loc[(test['Elevation'] < 50), 'Is_Site'] = 0


test.loc[(test['NEAR_DIST_Chert'] > 20000), 'Is_Site'] = 0
test.loc[(test['NEAR_DIST_Coastal'] > 6000), 'Is_Site'] = 0
# test.loc[(test['NEAR_DIST_Canals'] < 20000), 'Is_Site'] = 0
# test.loc[(test['NEAR_DIST_River_Net'] < 20000), 'Is_Site'] = 0


test['Is_Site'] = test['Is_Site'].astype(np.uint8)

test.to_csv(data_path / 'test_labeled.csv', index=False)

test['Is_Site'].value_counts()
# Out:
# Is_Site
# 0    10769
# 1     1297
# Name: count, dtype: int64

# %%
rng = np.random.RandomState()

RNG_MIX = 0.01

rng_selection = test[test['Is_Site'] == 0]
rng_nums = rng.choice(
    a=rng_selection.index, 
    size=int(test['Is_Site'].value_counts()[0]*RNG_MIX), 
    replace=False
)

test_cut = test.drop(index=rng_nums) # pyright: ignore[reportArgumentType, reportCallIssue]

rng_sites = rng_selection.loc[rng_nums]

rng_sites
# Out:
#          Elevation  Wetness       Temp  Slope  NEAR_DIST_Chert  \
# 2666    273.824158        0  14.900000    247     19833.003844
# 5473   1070.443115        0   9.800000    249      5983.270933
# 511     233.356323        0  15.800000    250     29440.869702
# 11019  1266.715332        0   7.900000    227    129272.068314
# 8994    603.984680        0  11.400000    249     80172.802628
# ...            ...      ...        ...    ...              ...
# 10920  1018.554138        0  10.000000    231    126205.079655
# 5913    251.926620        0  15.300000    250      9037.736412
# 7152    897.890442        0  10.800000    231     16721.614219
# 9813   1089.098389        0   9.800000    245     21953.188560
# 1744    159.998016        0  16.299999    246     22025.718744
#
#        NEAR_DIST_Canals  NEAR_DIST_River_Net  NEAR_DIST_Coastal  Is_Site
# 2666      282798.092084         29274.721754       21169.322419        0
# 5473      272200.780968         20717.477132       34323.930662        0
# 511       312687.742838          8893.552488        4720.101456        0
# 11019     200910.021327         13370.053601       11556.930321        0
# 8994      217711.667734         22920.477053       20481.299817        0
# ...                 ...                  ...                ...      ...
# 10920     203559.857992         18732.592396        3517.813489        0
# 5913      263433.880200         18327.325836       36933.429573        0
# 7152      264972.084237         17819.055430       43038.398781        0
# 9813      246592.684047         27613.635734       53994.799046        0
# 1744      325007.816498         33082.728589         444.355508        0
#
# [107 rows x 9 columns]

# %%
known_rng = pd.concat([known, rng_sites], ignore_index=True)

print(f'Using a combination of {known.shape[0]} known sites and {rng_sites.shape[0]} test sites for {known_rng.shape[0]} total test sites.')

known_rng
# Out:
# Using a combination of 47 known sites and 107 test sites for 154 total test sites.
#        Elevation  Wetness       Temp  Slope  NEAR_DIST_Chert  \
# 0      46.000000        0  15.700000    204    247901.167568
# 1     750.000000        0  11.000000    241    235748.803581
# 2     510.000000        0  12.400000    247    241293.250685
# 3     864.000000        0   9.700000    245    204549.089663
# 4      43.708790        0  15.700000    250    215799.109406
# ..           ...      ...        ...    ...              ...
# 149  1018.554138        0  10.000000    231    126205.079655
# 150   251.926620        0  15.300000    250      9037.736412
# 151   897.890442        0  10.800000    231     16721.614219
# 152  1089.098389        0   9.800000    245     21953.188560
# 153   159.998016        0  16.299999    246     22025.718744
#
#      NEAR_DIST_Canals  NEAR_DIST_River_Net  NEAR_DIST_Coastal  Is_Site
# 0        80993.524258         73640.087050        7612.808936        1
# 1        98999.561639         44437.690620        9921.595682        1
# 2       101016.428031         34876.914519       14119.067154        1
# 3       143240.912311         13416.969148       15491.977574        1
# 4       114332.595817         94426.986888        2230.743465        1
# ..                ...                  ...                ...      ...
# 149     203559.857992         18732.592396        3517.813489        0
# 150     263433.880200         18327.325836       36933.429573        0
# 151     264972.084237         17819.055430       43038.398781        0
# 152     246592.684047         27613.635734       53994.799046        0
# 153     325007.816498         33082.728589         444.355508        0
#
# [154 rows x 9 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(known_rng.drop(columns=['Is_Site']), known_rng['Is_Site'], test_size=0.25, stratify=known_rng['Is_Site'])

# %%
model = xgb.XGBClassifier(tree_method='hist')

model.fit(X_train, y_train, eval_set=[(X_test, y_test)])

y_pred = model.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred.round())*100}%')
# Out:
# [0]	validation_0-logloss:0.51054
# [1]	validation_0-logloss:0.45924
# [2]	validation_0-logloss:0.42576
# [3]	validation_0-logloss:0.36756
# [4]	validation_0-logloss:0.35347
# [5]	validation_0-logloss:0.32472
# [6]	validation_0-logloss:0.30706
# [7]	validation_0-logloss:0.29604
# [8]	validation_0-logloss:0.27587
# [9]	validation_0-logloss:0.26971
# [10]	validation_0-logloss:0.26255
# [11]	validation_0-logloss:0.25688
# [12]	validation_0-logloss:0.25636
# [13]	validation_0-logloss:0.25961
# [14]	validation_0-logloss:0.25338
# [15]	validation_0-logloss:0.25930
# [16]	validation_0-logloss:0.25842
# [17]	validation_0-logloss:0.25571
# [18]	validation_0-logloss:0.25653
# [19]	validation_0-logloss:0.25507
# [20]	validation_0-logloss:0.25465
# [21]	validation_0-logloss:0.25554
# [22]	validation_0-logloss:0.25437
# [23]	validation_0-logloss:0.25767
# [24]	validation_0-logloss:0.26175
# [25]	validation_0-logloss:0.26147
# [26]	validation_0-logloss:0.26054
# [27]	validation_0-logloss:0.25679
# [28]	validation_0-logloss:0.25875
# [29]	validation_0-logloss:0.25960
# [30]	validation_0-logloss:0.26000
# [31]	validation_0-logloss:0.26216
# [32]	validation_0-logloss:0.26253
# [33]	validation_0-logloss:0.26471
# [34]	validation_0-logloss:0.26543
# [35]	validation_0-logloss:0.26617
# [36]	validation_0-logloss:0.26693
# [37]	validation_0-logloss:0.26651
# [38]	validation_0-logloss:0.26683
# [39]	validation_0-logloss:0.26721
# [40]	validation_0-logloss:0.26484
# [41]	validation_0-logloss:0.26591
# [42]	validation_0-logloss:0.26676
# [43]	validation_0-logloss:0.26473
# [44]	validation_0-logloss:0.26464
# [45]	validation_0-logloss:0.26452
# [46]	validation_0-logloss:0.26599
# [47]	validation_0-logloss:0.26591
# [48]	validation_0-logloss:0.26690
# [49]	validation_0-logloss:0.26816
# [50]	validation_0-logloss:0.26745
# [51]	validation_0-logloss:0.26728
# [52]	validation_0-logloss:0.26689
# [53]	validation_0-logloss:0.26803
# [54]	validation_0-logloss:0.26985
# [55]	validation_0-logloss:0.27417
# [56]	validation_0-logloss:0.27539
# [57]	validation_0-logloss:0.27482
# [58]	validation_0-logloss:0.27429
# [59]	validation_0-logloss:0.27442
# [60]	validation_0-logloss:0.27489
# [61]	validation_0-logloss:0.27603
# [62]	validation_0-logloss:0.27583
# [63]	validation_0-logloss:0.27739
# [64]	validation_0-logloss:0.27565
# [65]	validation_0-logloss:0.27515
# [66]	validation_0-logloss:0.27737
# [67]	validation_0-logloss:0.27703
# [68]	validation_0-logloss:0.27702
# [69]	validation_0-logloss:0.28018
# [70]	validation_0-logloss:0.27881
# [71]	validation_0-logloss:0.27939
# [72]	validation_0-logloss:0.28369
# [73]	validation_0-logloss:0.28516
# [74]	validation_0-logloss:0.28369
# [75]	validation_0-logloss:0.28493
# [76]	validation_0-logloss:0.28468
# [77]	validation_0-logloss:0.28471
# [78]	validation_0-logloss:0.28448
# [79]	validation_0-logloss:0.28546
# [80]	validation_0-logloss:0.28747
# [81]	validation_0-logloss:0.28851
# [82]	validation_0-logloss:0.29004
# [83]	validation_0-logloss:0.28862
# [84]	validation_0-logloss:0.28714
# [85]	validation_0-logloss:0.28700
# [86]	validation_0-logloss:0.28758
# [87]	validation_0-logloss:0.28878
# [88]	validation_0-logloss:0.28760
# [89]	validation_0-logloss:0.28575
# [90]	validation_0-logloss:0.28642
# [91]	validation_0-logloss:0.28861
# [92]	validation_0-logloss:0.28709
# [93]	validation_0-logloss:0.28764
# [94]	validation_0-logloss:0.29102
# [95]	validation_0-logloss:0.29064
# [96]	validation_0-logloss:0.28970
# [97]	validation_0-logloss:0.28937
# [98]	validation_0-logloss:0.29043
# [99]	validation_0-logloss:0.29040
# Accuracy: 87.17948717948718%

# %%
outcome = test_cut.drop(columns=['Is_Site'])
outcome['prediction'] = model.predict(outcome)

outcome
# Out:
#         Elevation  Wetness       Temp  Slope  NEAR_DIST_Chert  \
# 0       70.596275        0  16.799999    207     27245.870159
# 1      227.165344        0  16.400000    243     25924.985926
# 2       41.271420        0  17.100000    236     24605.088261
# 3       58.482124        0  16.500000    232     24494.102940
# 4       22.511099        0  17.000000    242       792.107078
# ...           ...      ...        ...    ...              ...
# 12061  551.129211        0  10.300000    250     90956.384346
# 12062  659.387390        0   9.800000    222     91942.567948
# 12063  337.125427        0  11.300000    216     88604.594675
# 12064  400.164185        0  10.900000    236     89592.956286
# 12065  532.479248        0  10.900000    245     88239.645786
#
#        NEAR_DIST_Canals  NEAR_DIST_River_Net  NEAR_DIST_Coastal  prediction
# 0         325051.049972         92375.044496         109.719805           1
# 1         326171.018246         91240.568066         521.790859           1
# 2         327292.421342         90111.311563         128.050137           1
# 3         326739.480379         89566.947218         238.350808           1
# 4         376552.349498         77429.587911          45.335448           1
# ...                 ...                  ...                ...         ...
# 12061     184989.356662          2271.270992       59132.748107           0
# 12062     183977.412603          3259.110714       59923.992081           0
# 12063     186768.663311            41.657071       58440.290816           0
# 12064     185754.992778          1064.431584       59204.693096           0
# 12065     186531.839857           588.634010       59323.222735           0
#
# [11959 rows x 9 columns]

# %%
outcome['prediction'].value_counts()
# Out:
# prediction
# 0    9774
# 1    2185
# Name: count, dtype: int64

# %%
outcome_linked = outcome.merge(test_cleaned[['OBJECTID', 'x', 'y']], left_index=True, right_index=True)
outcome_linked
# Out:
#         Elevation  Wetness       Temp  Slope  NEAR_DIST_Chert  \
# 0       70.596275        0  16.799999    207     27245.870159
# 1      227.165344        0  16.400000    243     25924.985926
# 2       41.271420        0  17.100000    236     24605.088261
# 3       58.482124        0  16.500000    232     24494.102940
# 4       22.511099        0  17.000000    242       792.107078
# ...           ...      ...        ...    ...              ...
# 12061  551.129211        0  10.300000    250     90956.384346
# 12062  659.387390        0   9.800000    222     91942.567948
# 12063  337.125427        0  11.300000    216     88604.594675
# 12064  400.164185        0  10.900000    236     89592.956286
# 12065  532.479248        0  10.900000    245     88239.645786
#
#        NEAR_DIST_Canals  NEAR_DIST_River_Net  NEAR_DIST_Coastal  prediction  \
# 0         325051.049972         92375.044496         109.719805           1
# 1         326171.018246         91240.568066         521.790859           1
# 2         327292.421342         90111.311563         128.050137           1
# 3         326739.480379         89566.947218         238.350808           1
# 4         376552.349498         77429.587911          45.335448           1
# ...                 ...                  ...                ...         ...
# 12061     184989.356662          2271.270992       59132.748107           0
# 12062     183977.412603          3259.110714       59923.992081           0
# 12063     186768.663311            41.657071       58440.290816           0
# 12064     185754.992778          1064.431584       59204.693096           0
# 12065     186531.839857           588.634010       59323.222735           0
#
#        OBJECTID          x          y
# 0          3353  15.726739  43.023390
# 1          3357  15.743060  43.023390
# 2          3362  15.759382  43.023390
# 3          3410  15.759382  43.032675
# 4           183  16.510161  42.763406
# ...         ...        ...        ...
# 12061     25454  16.004201  44.666859
# 12062     25455  16.004201  44.676145
# 12063     25456  16.004201  44.685430
# 12064     25457  16.020522  44.657574
# 12065     25458  16.020522  44.666859
#
# [11958 rows x 12 columns]

# %%
outcome_linked[(outcome_linked['y'] <= 43.57) & (outcome_linked['prediction'] == 1)].shape
# Out:
# (1071, 12)

# %%
# %%script True
# outcome_linked.to_csv(data_path / f'test_predictions_{RNG_MIX}.csv', index=False)
# outcome_linked[outcome_linked['prediction'] == 1].to_csv(data_path / f'test_predictions_sites_{RNG_MIX}.csv', index=False)
# Out:
# Couldn't find program: 'True'
