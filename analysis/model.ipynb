# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from pathlib import Path
import warnings

warnings.filterwarnings('ignore')

data_path = Path().cwd() / 'data'

# %%
test_sites = pd.read_excel(data_path / 'test_points_250_augmented.xls', engine='calamine')

for col in test_sites.columns:
    if 'NEAR_FID' in col:
        test_sites.drop(columns=[col], inplace=True)

print(test_sites.shape)
test_sites.head()
# Out:
# (62500, 30)
#    OBJECTID      x          y  NEAR_DIST_Canals  NEAR_DIST_River_Net  \
# 0         1  13.47  42.900000     207093.263943         46226.866869
# 1         2  13.47  42.911124     205993.497244         47071.385234
# 2         3  13.47  42.922249     204895.278855         46452.892775
# 3         4  13.47  42.933373     203798.633851         45363.522840
# 4         5  13.47  42.944498     202703.587813         44281.842118
#
#    NEAR_DIST_Coastal  WAW_2018_010m_E45N24_03035_v020  \
# 0       34265.278322                              NaN
# 1       33931.780558                              NaN
# 2       33639.451597                              NaN
# 3       33361.113072                              NaN
# 4       33053.372197                              NaN
#
#    WAW_2018_010m_E46N23_03035_v020  WAW_2018_010m_E46N24_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E46N25_03035_v020  ...  WAW_2018_010m_E48N26_03035_v020  \
# 0                              NaN  ...                              NaN
# 1                              NaN  ...                              NaN
# 2                              NaN  ...                              NaN
# 3                              NaN  ...                              NaN
# 4                              NaN  ...                              NaN
#
#    WAW_2018_010m_E49N21_03035_v020  WAW_2018_010m_E49N22_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E49N24_03035_v020  WAW_2018_010m_E49N25_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E50N21_03035_v020  WAW_2018_010m_E50N22_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E50N24_03035_v020  WAW_2018_010m_E50N25_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    RASTERVALU
# 0  684.918945
# 1  714.755615
# 2  643.646973
# 3  721.607910
# 4  668.033020
#
# [5 rows x 30 columns]

# %%
def clean_waw(df: pd.DataFrame):
    wcols = [col for col in df.columns if 'WAW' in col]
    waw = df[wcols + ['OBJECTID']]
    df.drop(columns=wcols, inplace=True)
    
    waw['Wetness'] = waw[waw.drop(['OBJECTID'], axis=1).columns].apply(
        lambda x: ''.join(x.dropna().astype(str)), 
        axis=1
    )
    
    waw = waw[waw['Wetness'] != ''][['OBJECTID', 'Wetness']]
    waw['Wetness'] = waw['Wetness'].astype(float).astype(np.uint8)
    return pd.merge(df, waw, on='OBJECTID', how='inner')

# %%
test_cleaned = clean_waw(test_sites)
test_cleaned
# Out:
#        OBJECTID          x          y  NEAR_DIST_Canals  NEAR_DIST_River_Net  \
# 0          2305  14.638835  42.900000     264085.099158         56892.951994
# 1          2306  14.638835  42.911124     263214.289583         57499.260687
# 2          2307  14.638835  42.922249     262346.407780         58124.344920
# 3          2308  14.638835  42.933373     261481.482935         58768.598461
# 4          2309  14.638835  42.944498     260619.544523         59431.570137
# ...         ...        ...        ...               ...                  ...
# 54504     62496  17.750000  45.625502     105027.866058         17814.128968
# 54505     62497  17.750000  45.636627     104132.352826         16739.232836
# 54506     62498  17.750000  45.647751     103243.877082         15687.704093
# 54507     62499  17.750000  45.658876     102362.622161         14660.426707
# 54508     62500  17.750000  45.670000     101488.776255         13667.831348
#
#        NEAR_DIST_Coastal  RASTERVALU  Wetness
# 0           54210.207719         NaN      255
# 1           54760.100889         NaN      255
# 2           55294.040077         NaN      255
# 3           55827.978331         NaN      255
# 4           56361.915634         NaN      255
# ...                  ...         ...      ...
# 54504      231236.263512  180.351395        0
# 54505      232037.548592  142.631439        0
# 54506      232842.641684  194.935699        0
# 54507      233651.503463  204.853287        0
# 54508      234464.094962  153.258362        0
#
# [54509 rows x 8 columns]

# %%
display(test_cleaned.isna().sum().to_frame().T)

test_cleaned.fillna(0, inplace=True)

display(test_cleaned.isna().sum().to_frame().T)
# Out:
#    OBJECTID  x  y  NEAR_DIST_Canals  NEAR_DIST_River_Net  NEAR_DIST_Coastal  \
# 0         0  0  0                 0                    0                  0
#
#    RASTERVALU  Wetness
# 0       20101        0
#    OBJECTID  x  y  NEAR_DIST_Canals  NEAR_DIST_River_Net  NEAR_DIST_Coastal  \
# 0         0  0  0                 0                    0                  0
#
#    RASTERVALU  Wetness
# 0           0        0

# %%
known_sites = pd.read_excel(data_path / 'known_sites_augmented.xls', engine='calamine')

known_sites.rename(columns={
        i: i.replace('sites_XYTableToPoint_', '') for i in known_sites.columns if 'sites_XYTableToPoint_' in i
    }, inplace=True)

known_sites.rename(columns={
    'Elevation__Masl_': 'Elevation'
    }, inplace=True)

known_sites.drop(columns=['Dd', 'Dms'] + [col for col in known_sites.columns if 'NEAR_FID' in col], inplace=True)

print(known_sites.shape)
known_sites.head()
# Out:
# (47, 37)
#    OBJECTID                Site_Name Geographical_Region  \
# 0         1         Abri Kontija 002               Istra
# 1         2               Abri Šebrn                 NaN
# 2         3  Brjgućeva Loza 1 (Loza)               Istra
# 3         4                  Bukovac                 NaN
# 4         5                 Campanož                 NaN
#
#   Geographical_Location  Elevation Period_New Site_Type      Dd_ns      Dd_ew  \
# 0          Limski kanal       46.0         UP        RS  45.137500  13.718611
# 1                   NaN      750.0        MES        RS  45.337712  14.162687
# 2                Kastav      510.0        MES         C  45.467778  14.242222
# 3                   NaN      864.0         UP         C  45.346569  14.756238
# 4                   NaN        NaN         MP         O  44.849045  13.899990
#
#    NEAR_DIST_Chert  ...  WAW_2018_010m_E48N25_03035_v020  \
# 0    247901.167568  ...                              NaN
# 1    235748.803581  ...                              NaN
# 2    241293.250685  ...                              NaN
# 3    204549.089663  ...                              NaN
# 4    215799.109406  ...                              NaN
#
#    WAW_2018_010m_E48N26_03035_v020  WAW_2018_010m_E49N21_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E49N22_03035_v020  WAW_2018_010m_E49N24_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E49N25_03035_v020  WAW_2018_010m_E50N21_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E50N22_03035_v020  WAW_2018_010m_E50N24_03035_v020  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    WAW_2018_010m_E50N25_03035_v020
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 37 columns]

# %%
known_sites_cleaned = clean_waw(known_sites).drop(columns=['Geographical_Region', 'Geographical_Location'])

print(known_sites_cleaned.shape)
known_sites_cleaned.head()
# Out:
# (47, 13)
#    OBJECTID                Site_Name  Elevation Period_New Site_Type  \
# 0         1         Abri Kontija 002       46.0         UP        RS
# 1         2               Abri Šebrn      750.0        MES        RS
# 2         3  Brjgućeva Loza 1 (Loza)      510.0        MES         C
# 3         4                  Bukovac      864.0         UP         C
# 4         5                 Campanož        NaN         MP         O
#
#        Dd_ns      Dd_ew  NEAR_DIST_Chert  NEAR_DIST_Canals  \
# 0  45.137500  13.718611    247901.167568      80993.524258
# 1  45.337712  14.162687    235748.803581      98999.561639
# 2  45.467778  14.242222    241293.250685     101016.428031
# 3  45.346569  14.756238    204549.089663     143240.912311
# 4  44.849045  13.899990    215799.109406     114332.595817
#
#    NEAR_DIST_River_Net  NEAR_DIST_Coastal  RASTERVALU  Wetness
# 0         73640.087050        7612.808936   46.136692        0
# 1         44437.690620        9921.595682  732.561707        0
# 2         34876.914519       14119.067154  432.515076        0
# 3         13416.969148       15491.977574  791.070129        0
# 4         94426.986888        2230.743465   43.708790        0

# %%
cols = known_sites_cleaned.columns
known_sites_cleaned = known_sites_cleaned[cols[:3].to_list() + [cols[-2]] + cols[3:-2].to_list() + [cols[-1]]]
known_sites_cleaned.head()
# Out:
#    OBJECTID                Site_Name  Elevation  RASTERVALU Period_New  \
# 0         1         Abri Kontija 002       46.0   46.136692         UP
# 1         2               Abri Šebrn      750.0  732.561707        MES
# 2         3  Brjgućeva Loza 1 (Loza)      510.0  432.515076        MES
# 3         4                  Bukovac      864.0  791.070129         UP
# 4         5                 Campanož        NaN   43.708790         MP
#
#   Site_Type      Dd_ns      Dd_ew  NEAR_DIST_Chert  NEAR_DIST_Canals  \
# 0        RS  45.137500  13.718611    247901.167568      80993.524258
# 1        RS  45.337712  14.162687    235748.803581      98999.561639
# 2         C  45.467778  14.242222    241293.250685     101016.428031
# 3         C  45.346569  14.756238    204549.089663     143240.912311
# 4         O  44.849045  13.899990    215799.109406     114332.595817
#
#    NEAR_DIST_River_Net  NEAR_DIST_Coastal  Wetness
# 0         73640.087050        7612.808936        0
# 1         44437.690620        9921.595682        0
# 2         34876.914519       14119.067154        0
# 3         13416.969148       15491.977574        0
# 4         94426.986888        2230.743465        0

# %%
known_sites_cleaned.isna().sum().to_frame().T
# Out:
#    OBJECTID  Site_Name  Elevation  RASTERVALU  Period_New  Site_Type  Dd_ns  \
# 0         0          0         12           5           0          0      0
#
#    Dd_ew  NEAR_DIST_Chert  NEAR_DIST_Canals  NEAR_DIST_River_Net  \
# 0      0                0                 0                    0
#
#    NEAR_DIST_Coastal  Wetness
# 0                  0        0

# %%
known_sites_cleaned.Elevation.fillna(known_sites_cleaned.RASTERVALU, inplace=True)

known_sites_cleaned
# Out:
#     OBJECTID                         Site_Name   Elevation  RASTERVALU  \
# 0          1                  Abri Kontija 002   46.000000   46.136692
# 1          2                        Abri Šebrn  750.000000  732.561707
# 2          3           Brjgućeva Loza 1 (Loza)  510.000000  432.515076
# 3          4                           Bukovac  864.000000  791.070129
# 4          5                          Campanož   43.708790   43.708790
# 5          6                  Cerovačke pećine  624.000000  596.050293
# 6          7          Giljanovići (Karanušići)  154.000000  370.460022
# 7          8                         Glavičica  295.000000  297.810455
# 8          9                  Gospodska špilja  430.000000  424.836060
# 9         10                   Igraliste-Dolac   16.000000   16.647577
# 10        11                           Ivšišće   24.520134   24.520134
# 11        12                     Jami na sredi  102.000000   52.862606
# 12        13          Kaštel Štafilić – Resnik         NaN         NaN
# 13        14                     Klanjčeva peć  828.000000  872.622498
# 14        15                     Kopačina cave  280.000000  341.804962
# 15        16             Krševanje polje, Sali   23.944098   23.944098
# 16        17                           Lim 001         NaN         NaN
# 17        18                  Ljubićeva pećina  170.000000  193.253708
# 18        19                             Lopar   20.000000   77.727386
# 19        20                  Malo Polje Krban   19.260384   19.260384
# 20        21                     Mujina pećina  260.000000   43.181072
# 21        22                           Okruglo  297.810455  297.810455
# 22        23  Panjorovica/Panđerovica Veli Rat    8.000000    6.848802
# 23        24                 Pećina na Gradini  393.000000  310.115326
# 24        25      Pećina kod Rovinjskog Sela 1   71.000000   99.617897
# 25        26            Pećina u Brini zapadna  250.000000  443.155518
# 26        27                     Podosojna peć  335.000000  947.815369
# 27        28               Podumci kod Unešića  295.000000  437.297821
# 28        29                             Polje    4.000000    2.933673
# 29        30                   Ražanac cluster  102.495941  102.495941
# 30        31                 Romualdova pećina  110.000000   60.497437
# 31        32                         Savudrija    5.337913    5.337913
# 32        33      Stipanac, Prokljansko Jezero         NaN         NaN
# 33        34                            Straža   20.000000   22.127819
# 34        35                       Šandalja II   72.000000   58.747875
# 35        36               Uvala čuna-Darstalo    1.000000         NaN
# 36        37                   Uvala Jaz-Polje    1.000000         NaN
# 37        38     Valačin žal- Uvala Podlokvanj    2.000000    0.028626
# 38        39                Vela Spila Korčula  130.000000  121.023857
# 39        40       Vela Jama/spilja na Lošinju  450.000000  299.411102
# 40        41           Velika pećina Kličevica  125.000000  122.749153
# 41        42                Vergotinova pećina   85.000000   92.716667
# 42        43                    Vorganjska peć  251.000000   31.882753
# 43        44                            Vlakno   38.000000   14.104102
# 44        45                   Zametska pećina  140.000000  147.718292
# 45        46                 Zapuntelsko polje   28.055592   28.055592
# 46        47                          Zemunica  591.057983  591.057983
#
#       Period_New   Site_Type      Dd_ns      Dd_ew  NEAR_DIST_Chert  \
# 0             UP          RS  45.137500  13.718611    247901.167568
# 1            MES          RS  45.337712  14.162687    235748.803581
# 2            MES           C  45.467778  14.242222    241293.250685
# 3             UP           C  45.346569  14.756238    204549.089663
# 4             MP           O  44.849045  13.899990    215799.109406
# 5             UP           C  44.274628  15.884619     55816.576622
# 6             MP           O  43.940833  16.426389      8763.044136
# 7        UP, MES           O  43.749998  16.666664     16125.218641
# 8        UP, MES           C  43.983887  16.436379     12714.582519
# 9             MP           O  44.142032  14.841416    108346.908403
# 10            UP           O  45.198816  14.098523    229615.033310
# 11           MES           C  44.666660  14.466665    169087.564495
# 12            MP  underwater  43.538609  16.312500      1015.417553
# 13       UP, MES           C  45.333050  14.187772    233944.879546
# 14      LUP, MES           C  43.353049  16.552514      4960.723478
# 15     MP,UP,MES           O  43.916839  15.154990     73594.575338
# 16           MES          RS  45.133916  13.731182    246911.612526
# 17           LUP           C  44.971800  13.951898    221892.824957
# 18       UP, MES           O  44.833333  14.750000    164142.625069
# 19            MP           O  43.525783  16.264043      1100.235621
# 20            MP           C  43.525775  16.244627      1516.954994
# 21       UP, MES           O  43.750000  16.666667     16125.508022
# 22            MP           O  44.150237  14.827839    109760.311095
# 23           EUP           C  45.333332  14.499993    216549.206854
# 24      LUP, MES           C  45.126527  13.703193    247940.859038
# 25            UP           C  43.833331  16.166664     15386.116678
# 26           MES           C  45.260578  14.198106    227981.751358
# 27           MES           O  43.716667  16.133333     15547.831158
# 28            MP           O  44.134675  14.861064    106591.594746
